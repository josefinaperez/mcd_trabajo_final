# %% [markdown]
# # Análisis exploratorio de dataset de gbif
#
# Análisis de los datos descargados de gbif ya filtrados.

# %% [markdown]
# ## Librerías y ambiente

# %%
import sys
from pathlib import Path

ROOT = Path().resolve().parents[0]
sys.path.append(str(ROOT))

# %%
import pandas as pd
from src.utils.plot import plot_points
from src.config import ARG_SHP_PATH, STA_FE_SHP_PATH

# %% [markdown]
# ## Análisis

# %%
plot_points(ARG_SHP_PATH, '../data/filtered/df_trametes_sanguinea_argentina.csv')

# %%
plot_points(STA_FE_SHP_PATH, '../data/filtered/df_trametes_sanguinea_santa_fe.csv')
