# %% [markdown]
# # Análisis exploratorio de data raw de gbif
#
# Análisis de los datos descargados de gbif para evaluar pasos de limpieza.

# %% [markdown]
# ## Librerías y ambiente

# %%
import sys
from pathlib import Path

ROOT = Path().resolve().parents[0]
sys.path.append(str(ROOT))

# %%
import pandas as pd

# %% [markdown]
# ## Análisis

# %%
df_raw = pd.read_csv('../data/raw/df_trametes_sanguinea.csv')
df_raw.head()
# Out:
#    Unnamed: 0         key                            datasetKey  \
# 0           0  5007775853  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1           1  5007900444  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2           2  5036742586  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3           3  5037098754  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4           4  5037144192  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                        publishingOrgKey                       installationKey  \
# 0  28eb1a3f-1c15-4a95-931a-4af90ecb574d  997448a8-f762-11e1-a439-00145eb45e9a
# 1  28eb1a3f-1c15-4a95-931a-4af90ecb574d  997448a8-f762-11e1-a439-00145eb45e9a
# 2  28eb1a3f-1c15-4a95-931a-4af90ecb574d  997448a8-f762-11e1-a439-00145eb45e9a
# 3  28eb1a3f-1c15-4a95-931a-4af90ecb574d  997448a8-f762-11e1-a439-00145eb45e9a
# 4  28eb1a3f-1c15-4a95-931a-4af90ecb574d  997448a8-f762-11e1-a439-00145eb45e9a
#
#                  hostingOrganizationKey publishingCountry     protocol  \
# 0  28eb1a3f-1c15-4a95-931a-4af90ecb574d                US  DWC_ARCHIVE
# 1  28eb1a3f-1c15-4a95-931a-4af90ecb574d                US  DWC_ARCHIVE
# 2  28eb1a3f-1c15-4a95-931a-4af90ecb574d                US  DWC_ARCHIVE
# 3  28eb1a3f-1c15-4a95-931a-4af90ecb574d                US  DWC_ARCHIVE
# 4  28eb1a3f-1c15-4a95-931a-4af90ecb574d                AR  DWC_ARCHIVE
#
#                      lastCrawled                     lastParsed  ...  \
# 0  2025-12-24T14:08:22.718+00:00  2025-12-25T06:16:59.298+00:00  ...
# 1  2025-12-24T14:08:22.718+00:00  2025-12-25T05:25:33.982+00:00  ...
# 2  2025-12-24T14:08:22.718+00:00  2025-12-25T03:50:47.119+00:00  ...
# 3  2025-12-24T14:08:22.718+00:00  2025-12-25T03:51:30.132+00:00  ...
# 4  2025-12-24T14:08:22.718+00:00  2025-12-25T03:51:37.150+00:00  ...
#
#    originalNameUsage nameAccordingTo georeferencedDate  \
# 0                NaN             NaN               NaN
# 1                NaN             NaN               NaN
# 2                NaN             NaN               NaN
# 3                NaN             NaN               NaN
# 4                NaN             NaN               NaN
#
#   distanceFromCentroidInMeters fieldNotes  http://unknown.org/taxonRankID  \
# 0                          NaN        NaN                             NaN
# 1                          NaN        NaN                             NaN
# 2                          NaN        NaN                             NaN
# 3                          NaN        NaN                             NaN
# 4                          NaN        NaN                             NaN
#
#    verbatimSRS  verbatimCoordinateSystem  http://unknown.org/species  \
# 0          NaN                       NaN                         NaN
# 1          NaN                       NaN                         NaN
# 2          NaN                       NaN                         NaN
# 3          NaN                       NaN                         NaN
# 4          NaN                       NaN                         NaN
#
#    taxonRemarks
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 169 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3071 entries, 0 to 3070
# Columns: 169 entries, Unnamed: 0 to taxonRemarks
# dtypes: bool(2), float64(24), int64(11), object(132)
# memory usage: 3.9+ MB

# %% [markdown]
# ### Campos de fecha
#
# Se conserva la columna eventDate que es la fecha normalizada de la observación. En este caso no interesa el horario.

# %%
date_cols = ['lastCrawled',
             'lastParsed',
             'dateIdentified',
             'eventDate',
             'year',
             'month',
             'day',
             'startDayOfYear',
             'endDayOfYear',
             'modified',
             'lastInterpreted',
             'verbatimEventDate',
             'eventTime']

df_raw[date_cols].describe()
# Out:
#               year        month          day  startDayOfYear  endDayOfYear
# count  3026.000000  2850.000000  2722.000000     2722.000000   2722.000000
# mean   2014.479511     6.073333    15.544453      170.735489    170.735489
# std      18.581082     3.188347     9.126960       98.270961     98.270961
# min    1876.000000     1.000000     1.000000        1.000000      1.000000
# 25%    2012.000000     4.000000     8.000000       91.000000     91.000000
# 50%    2020.000000     5.000000    16.000000      148.000000    148.000000
# 75%    2024.000000     9.000000    24.000000      260.000000    260.000000
# max    2025.000000    12.000000    31.000000      365.000000    365.000000

# %% [markdown]
# ### Geografía
#
# - Hay algunas observaciones con latitud longitud nulas (las que tienen geoprivacy 'private').

# %%
geo_cols = ['decimalLatitude',
            'decimalLongitude',
            'continent',
            'stateProvince',
            'coordinateUncertaintyInMeters',
            ]

df_geo = df_raw[geo_cols]
df_geo.head()
# Out:
#    decimalLatitude  decimalLongitude      continent           stateProvince  \
# 0       -32.284910        -60.693062  SOUTH_AMERICA                Santa Fe
# 1       -32.269503        -60.695390  SOUTH_AMERICA                Santa Fe
# 2       -34.154603        -58.537305  SOUTH_AMERICA            Buenos Aires
# 3       -23.689290        -64.820195  SOUTH_AMERICA                   Jujuy
# 4       -34.582583        -58.415888  SOUTH_AMERICA  Ciudad de Buenos Aires
#
#    coordinateUncertaintyInMeters
# 0                            NaN
# 1                            NaN
# 2                            4.0
# 3                         4702.0
# 4                           14.0

# %%
df_geo.isna().sum()
# Out:
# decimalLatitude                     0
# decimalLongitude                    0
# continent                          10
# stateProvince                     505
# coordinateUncertaintyInMeters    1573
# dtype: int64

# %%
df_raw.coordinateUncertaintyInMeters.describe() # se pueden filtrar las que tengan más uncertainty
# Out:
# count    1.498000e+03
# mean     5.406696e+03
# std      7.988577e+04
# min      1.000000e+00
# 25%      1.700000e+01
# 50%      1.600000e+02
# 75%      3.750000e+02
# max      2.362591e+06
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
df_raw[df_raw.coordinateUncertaintyInMeters > 5000].shape
# Out:
# (83, 169)

# %%
df_raw.continent.value_counts()
# Out:
# continent
# SOUTH_AMERICA    3060
# NORTH_AMERICA       1
# Name: count, dtype: int64

# %%
df_raw[df_raw.continent == 'NORTH_AMERICA'] # observación con country code erróneo
# Out:
#       Unnamed: 0         key                            datasetKey  \
# 2587        2587  3709724736  7625a91a-54fb-49cc-a916-6349169d2371
#
#                           publishingOrgKey  \
# 2587  7a6bdf66-ef5c-4a81-b731-2e328f4881eb
#
#                            installationKey  \
# 2587  4fd221cd-129c-404f-ab62-fdd2377d12ac
#
#                     hostingOrganizationKey publishingCountry protocol  \
# 2587  497c081b-8157-4287-bb5c-291a4c71439c                AR      EML
#
#                         lastCrawled                     lastParsed  ...  \
# 2587  2026-01-01T03:01:19.472+00:00  2026-01-01T03:01:31.740+00:00  ...
#
#       originalNameUsage nameAccordingTo georeferencedDate  \
# 2587                NaN             NaN               NaN
#
#      distanceFromCentroidInMeters fieldNotes  http://unknown.org/taxonRankID  \
# 2587                          NaN        NaN                             NaN
#
#       verbatimSRS  verbatimCoordinateSystem  http://unknown.org/species  \
# 2587          NaN                       NaN                         NaN
#
#       taxonRemarks
# 2587           NaN
#
# [1 rows x 169 columns]

# %% [markdown]
# ### Species guess and names

# %%
df_raw.scientificName.value_counts()
# Out:
# scientificName
# Polyporaceae                                             1490
# Trametes versicolor (L.) Lloyd                            119
# Trametes Fr., 1836                                        117
# Coltricia stuckertiana (Speg.) Rajchenb. & J.E.Wright     102
# SH1248940.09FU                                             74
#                                                          ...
# Poria perparadoxa (Speg.) Sacc.                             1
# Fomes australis (Fr.) Cooke                                 1
# Polyporus similis Berk.                                     1
# Fomes lividus (Kalchbr.) Sacc.                              1
# Daedalea elegans Spreng.                                    1
# Name: count, Length: 197, dtype: int64

# %%
df_raw.acceptedScientificName.value_counts()
# Out:
# acceptedScientificName
# Polyporaceae                                       1490
# Trametes versicolor (L.) Lloyd                      120
# Trametes Fr., 1836                                  117
# Trametes stuckertiana (Speg.) Speg.                 104
# SH1248940.09FU                                       74
#                                                    ...
# Xerotus Fr.                                           1
# Ganoderma multipileum Ding Hou                        1
# Perenniporia vanhulleae Decock & Ryvarden             1
# Ganoderma sanduense Hapuar., T.C.Wen & K.D.Hyde       1
# Truncospora livida (Kalchbr.) Zmitr.                  1
# Name: count, Length: 154, dtype: int64
