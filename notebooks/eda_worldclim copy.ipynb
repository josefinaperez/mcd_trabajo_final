# %% [markdown]
# # Análisis exploratorio de variables de Worldclim
#
# Análisis de los datos descargados de worldclim.
#
# https://www.worldclim.org/data/bioclim.html

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Librerías y ambiente

# %%
import sys
from pathlib import Path

ROOT = Path().resolve().parents[0]
sys.path.append(str(ROOT))

# %%
from src.utils.plot import plot_raster
from src.config import ARG_SHP_PATH, STA_FE_SHP_PATH

# %% [markdown]
# ## Análisis

# %% [markdown]
# ### Santa Fe / 30s

# %%
for i in range(1,19):
    plot_raster(shape_path=STA_FE_SHP_PATH,
        wc_path=f"../data/worldclim/wc2.1_30s_bio/wc2.1_30s_bio_{i}.tif",
        title=f"BIO{i}")

# %% [markdown]
# ### Argentina - 30s

# %%
for i in range(1,20):
    plot_raster(shape_path=ARG_SHP_PATH,
        wc_path=f"../data/worldclim/wc2.1_30s_bio/wc2.1_30s_bio_{i}.tif")
# Out:
# /Users/josefinaperez/Documents/MCD/Trabajo final/mcd_trabajo_final/venv/lib/python3.11/site-packages/matplotlib/colors.py:778: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N
# /Users/josefinaperez/Documents/MCD/Trabajo final/mcd_trabajo_final/venv/lib/python3.11/site-packages/matplotlib/colors.py:778: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N
# /Users/josefinaperez/Documents/MCD/Trabajo final/mcd_trabajo_final/venv/lib/python3.11/site-packages/matplotlib/colors.py:778: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N
# /Users/josefinaperez/Documents/MCD/Trabajo final/mcd_trabajo_final/venv/lib/python3.11/site-packages/matplotlib/colors.py:778: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N
# /Users/josefinaperez/Documents/MCD/Trabajo final/mcd_trabajo_final/venv/lib/python3.11/site-packages/matplotlib/colors.py:778: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N
# ...
