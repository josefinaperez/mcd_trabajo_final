# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

ROOT = Path().resolve().parents[0]
sys.path.append(str(ROOT))

# %%
from src.data.pipe import get_dataset
from src.config import STA_FE_SHP_PATH, ARG_SHP_PATH

df_clean = get_dataset(specie='Trametes sanguinea',
                             shape_path=ARG_SHP_PATH)
df_clean.shape
# Out:
# (1356, 7)
